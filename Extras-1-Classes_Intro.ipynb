# %% [markdown]
# # <center>Extras: An Introduction to Classes!</center>

# %% [markdown]
# Welcome to a short, two-part expansion on the series - here we're going to look at the power of **Classes** and all the exciting things we can do with them!
# <center>But first - what is a Class? </center>

# %% [markdown]
# ## Classes

# %% [markdown]
# Classes are an easy way to group <code>functions()</code> and <code>variables</code> together into an object that we can use. Once stored inside a class, we can look at variables kinda like a set of **attributes**, and functions kinda like a set of **actions**.

# %% [markdown]
# That sounds all fine and dandy doesn't it - but what does that actually look like? Well, lets think about a class to represent a dog!
#
# If a friend was telling you about their beloved pet, the things (or **attributes**) they'd probably mention are:
# - The dog's name 🏷
# - How old their pooch is 🎂
# - What breed the dog is 🐕‍🦺
# - If their dog is cute 🥺
#
# And if you asked them what their dog loved to do, some activities (or **actions**) they'd probably mention are:
# - Bark 🔉
# - Dig 💪
# - Walkies 🚶‍♂️
#
# So lets take these and make a class to represent my dog: He is a **Daschund** called **Beans**. He is only **2** years old and *of course* he **is cute**!✨✨

# %% [markdown]
# <center><img src="attachment:ab373e4e-6323-47a5-8c8a-a22e6c11cce6.jpg" ...></center>

# %% [markdown]
# Just like how we used the <code>def</code> keyword to tell python we're writing a function, we use the <code>class</code> keyword here, a **colon** and then **indent** everything we want to be inside the class.
# Once the indent ends, any further code will not belong to the class.

# %% [markdown]
# ```python
# # Here's what a class containing my own dog's attributes stored as variables would look like
# class Dog:
#     name = "Beans"
#     age = 2
#     breed = "Daschund"
#     cute = True
# ```
# Notice how we used a mixture of **string**, **integer** and **boolean** variables? There are no restrictions to how you build your classes!
#
# Now let's add the actions! We'll add these as functions to our class:

# %%
# Run this cell to create the class so we can use it later!

class Dog:
    # Variables
    name = "Beans"
    age = 2
    breed = "Daschund"
    cute = True
    
    # Functions
    def bark():
        print("Woof!")        # This line of code is indented again, and so will only execute if the function above is called!
    
    def dig():
        print("Beans made a mess!")
    
    def walkies():
        print("Beans looks happy and tired now")

# %% [markdown]
# We can access the variables and functions inside the class by using the <code>.</code> operator. <br>
# If I wanted to see what **breed** <code>Dog</code> is and if it's **cute** then I would use the cell below to print the attributes:

# %%
print(Dog.breed, Dog.cute)

# %% [markdown]
# We access the class' **functions** in the same way with the <code>.</code> operator. Why don't you try to <code>print()</code> the <code>age</code> variable and then get Beans to <code>bark()</code> in the cell below:

# %%
# Write your two lines of code underneath this comment:

# %% [markdown]
# ## Have a Go!
# Good job! So hopefully the idea behind building classes is starting to come together in your head. To consolidate this, why don't you build your own <code>class</code> to represent a dog. This could be your own dog if you have one, your dream-dog if you don't or anything fluffy and four-legged your imagination runs to!
#
# Here's a few helpful **Hints** 📝:
# - Create a class called MyDog (remember your colon and indents!)
# - Using some appropriately named variables, store your dog's
#    - Name 🏷
#    - Age 🎂
#    - Breed 🐕‍🦺
#    - and if it's cute or not 🥺
# - Write some new functions that represent actions you'd not be surprised to see a dog doing (think eating, chasing cats etc)
#     - For each of these functions, write some <code>print</code> statement that shows the function was called

# %%
# Write your class here! If you get a little stuck, refer back to the code for Beans

# %% [markdown]
# What an awesome sounding dog 😎 <br>Lets test each function and variable's value in the cell below:

# %%
# Print your variables and call your functions in here to check they're all working!

# %% [markdown]
# Congrats! In the code above, we wrote two classes to specifically represent two dogs but there are other dogs out there too (we're very lucky I know). In the next **Extras** notebook, I'll show you how to write one template class to represent every dog! Well done, and I'll see you in the next notebook 😀
